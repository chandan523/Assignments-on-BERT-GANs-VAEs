# %% [markdown]
# First, import the necessary packages.

# %%
#Import the libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Layer, Conv2D, Flatten, Dense, Reshape, Conv2DTranspose
import matplotlib.pyplot as plt

# %% [markdown]
# In VAEs, the sampling layer uses the output from two dense layers, z_mean and z_log_var, as inputs, followed by converting them into the normal distribution and passing them to the decoder layer.

# %%
#Sampling layer
class Sampling(Layer):

	def call(self, inputs):
		z_mean, z_log_var = inputs
		batch = tf.shape(z_mean)[0]
		dim = tf.shape(z_mean)[1]
		epsilon = tf.keras.backend.random_normal(shape =(batch, dim))
		return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# Here, we are defining the architecture of the encoder part of this autoencoder, which takes images as input, followed by encoding their representation in the sampling layer.

# %%
# Define Encoder Model
latent_dim = 2

encoder_inputs = Input(shape =(28, 28, 1))
x = Conv2D(32, 3, activation ="relu", strides = 2, padding ="same")(encoder_inputs)
x = Conv2D(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Flatten()(x)
x = Dense(16, activation ="relu")(x)
z_mean = Dense(latent_dim, name ="z_mean")(x)
z_log_var = Dense(latent_dim, name ="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name ="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 14, 14, 32)           320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)             18496     ['conv2d[0][0]']
#
#  flatten (Flatten)           (None, 3136)                 0         ['conv2d_1[0][0]']
#
#  dense (Dense)               (None, 16)                   50192     ['flatten[0][0]']
#
#  z_mean (Dense)              (None, 2)                    34        ['dense[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    34        ['dense[0][0]']
#
#  sampling (Sampling)         (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 69076 (269.83 KB)
# Trainable params: 69076 (269.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# In this step, we are defining the architecture of the decoder part of the autoencoder, where the output of the sampling layer is given as input and produces an output image of size (28, 28, 1) .

# %%
# Define Decoder Architecture
latent_inputs = keras.Input(shape =(latent_dim, ))
x = Dense(7 * 7 * 64, activation ="relu")(latent_inputs)
x = Reshape((7, 7, 64))(x)
x = Conv2DTranspose(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Conv2DTranspose(32, 3, activation ="relu", strides = 2, padding ="same")(x)
decoder_outputs = Conv2DTranspose(1, 3, activation ="sigmoid", padding ="same")(x)
decoder = Model(latent_inputs, decoder_outputs, name ="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 65089 (254.25 KB)
# Trainable params: 65089 (254.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# In this step, we are defining the complete variational autoencoder architecture, followed by defining the training procedure with loss functions.

# %%
#Define the complete variational autoencoder architecture
class VAE(keras.Model):
	def __init__(self, encoder, decoder, **kwargs):
		super(VAE, self).__init__(**kwargs)
		self.encoder = encoder
		self.decoder = decoder

	def train_step(self, data):
		if isinstance(data, tuple):
			data = data[0]
		with tf.GradientTape() as tape:
			z_mean, z_log_var, z = encoder(data)
			reconstruction = decoder(z)
			reconstruction_loss = tf.reduce_mean(
				keras.losses.binary_crossentropy(data, reconstruction)
			)
			reconstruction_loss *= 28 * 28
			kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
			kl_loss = tf.reduce_mean(kl_loss)
			kl_loss *= -0.5
			total_loss = reconstruction_loss + kl_loss
		grads = tape.gradient(total_loss, self.trainable_weights)
		self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
		return {
			"loss": total_loss,
			"reconstruction_loss": reconstruction_loss,
			"kl_loss": kl_loss,
		}

# %% [markdown]
# Here, we shall train the variational autoencoder model for 100 epochs after importing the fashion MNIST dataset.

# %%
#Load the fashion mnist dataset
(x_train, _), (x_test, _) = keras.datasets.fashion_mnist.load_data()
fmnist_images = np.concatenate([x_train, x_test], axis = 0)
#Expansion of dimension for adding a color map dimension
fmnist_images = np.expand_dims(fmnist_images, -1).astype("float32") / 255

#Compile and train the VAE model
vae = VAE(encoder, decoder)
vae.compile(optimizer ='rmsprop')
vae.fit(fmnist_images, epochs = 100, batch_size = 64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/100
# 1094/1094 [==============================] - 96s 87ms/step - loss: 305.3114 - reconstruction_loss: 299.8718 - kl_loss: 5.4396
# Epoch 2/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 278.6766 - reconstruction_loss: 274.6067 - kl_loss: 4.0699
# Epoch 3/100
# 1094/1094 [==============================] - 94s 86ms/step - loss: 272.1994 - reconstruction_loss: 268.4365 - kl_loss: 3.7629
# Epoch 4/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 268.6618 - reconstruction_loss: 264.9743 - kl_loss: 3.6876
# Epoch 5/100
# 1094/1094 [==============================] - 94s 86ms/step - loss: 266.4586 - reconstruction_loss: 262.7705 - kl_loss: 3.6881
# Epoch 6/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 264.8908 - reconstruction_loss: 261.2127 - kl_loss: 3.6781
# Epoch 7/100
# 1094/1094 [==============================] - 94s 86ms/step - loss: 263.6406 - reconstruction_loss: 259.9483 - kl_loss: 3.6923
# Epoch 8/100
# 1094/1094 [==============================] - 91s 84ms/step - loss: 262.6393 - reconstruction_loss: 258.9270 - kl_loss: 3.7123
# Epoch 9/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 261.7789 - reconstruction_loss: 258.0434 - kl_loss: 3.7355
# Epoch 10/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 260.9736 - reconstruction_loss: 257.2282 - kl_loss: 3.7454
# Epoch 11/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 260.4104 - reconstruction_loss: 256.6498 - kl_loss: 3.7606
# Epoch 12/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 259.8175 - reconstruction_loss: 256.0504 - kl_loss: 3.7671
# Epoch 13/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 259.3738 - reconstruction_loss: 255.5828 - kl_loss: 3.7910
# Epoch 14/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 258.9541 - reconstruction_loss: 255.1692 - kl_loss: 3.7848
# Epoch 15/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 258.6268 - reconstruction_loss: 254.8399 - kl_loss: 3.7869
# Epoch 16/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 258.3498 - reconstruction_loss: 254.5449 - kl_loss: 3.8049
# Epoch 17/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 258.0936 - reconstruction_loss: 254.2747 - kl_loss: 3.8189
# Epoch 18/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 257.8072 - reconstruction_loss: 253.9946 - kl_loss: 3.8126
# Epoch 19/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 257.5426 - reconstruction_loss: 253.7244 - kl_loss: 3.8182
# Epoch 20/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 257.3553 - reconstruction_loss: 253.5215 - kl_loss: 3.8338
# Epoch 21/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 257.1972 - reconstruction_loss: 253.3501 - kl_loss: 3.8471
# Epoch 22/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 257.0280 - reconstruction_loss: 253.1669 - kl_loss: 3.8611
# Epoch 23/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 256.7693 - reconstruction_loss: 252.9056 - kl_loss: 3.8637
# Epoch 24/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 256.5983 - reconstruction_loss: 252.7312 - kl_loss: 3.8671
# Epoch 25/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 256.4613 - reconstruction_loss: 252.5919 - kl_loss: 3.8694
# Epoch 26/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 256.3353 - reconstruction_loss: 252.4448 - kl_loss: 3.8905
# Epoch 27/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 256.1992 - reconstruction_loss: 252.3108 - kl_loss: 3.8884
# Epoch 28/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 256.0586 - reconstruction_loss: 252.1613 - kl_loss: 3.8973
# Epoch 29/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 255.8888 - reconstruction_loss: 251.9854 - kl_loss: 3.9035
# Epoch 30/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 255.7291 - reconstruction_loss: 251.8172 - kl_loss: 3.9119
# Epoch 31/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 255.5893 - reconstruction_loss: 251.6674 - kl_loss: 3.9220
# Epoch 32/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 255.5510 - reconstruction_loss: 251.6364 - kl_loss: 3.9146
# Epoch 33/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 255.4124 - reconstruction_loss: 251.4737 - kl_loss: 3.9387
# Epoch 34/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 255.2867 - reconstruction_loss: 251.3629 - kl_loss: 3.9238
# Epoch 35/100
# 1094/1094 [==============================] - 94s 86ms/step - loss: 255.1878 - reconstruction_loss: 251.2436 - kl_loss: 3.9442
# Epoch 36/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 255.1095 - reconstruction_loss: 251.1622 - kl_loss: 3.9473
# Epoch 37/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 255.0559 - reconstruction_loss: 251.1098 - kl_loss: 3.9462
# Epoch 38/100
# 1094/1094 [==============================] - 91s 84ms/step - loss: 254.9229 - reconstruction_loss: 250.9721 - kl_loss: 3.9508
# Epoch 39/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 254.8528 - reconstruction_loss: 250.8999 - kl_loss: 3.9528
# Epoch 40/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 254.7916 - reconstruction_loss: 250.8409 - kl_loss: 3.9508
# Epoch 41/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 254.6735 - reconstruction_loss: 250.7172 - kl_loss: 3.9563
# Epoch 42/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 254.5819 - reconstruction_loss: 250.6251 - kl_loss: 3.9569
# Epoch 43/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 254.5134 - reconstruction_loss: 250.5563 - kl_loss: 3.9571
# Epoch 44/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 254.4611 - reconstruction_loss: 250.4941 - kl_loss: 3.9670
# Epoch 45/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 254.3701 - reconstruction_loss: 250.3979 - kl_loss: 3.9722
# Epoch 46/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 254.3066 - reconstruction_loss: 250.3327 - kl_loss: 3.9739
# Epoch 47/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 254.2412 - reconstruction_loss: 250.2726 - kl_loss: 3.9685
# Epoch 48/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 254.2026 - reconstruction_loss: 250.2289 - kl_loss: 3.9738
# Epoch 49/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 254.1354 - reconstruction_loss: 250.1657 - kl_loss: 3.9696
# Epoch 50/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 254.1286 - reconstruction_loss: 250.1527 - kl_loss: 3.9759
# Epoch 51/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 254.0099 - reconstruction_loss: 250.0351 - kl_loss: 3.9748
# Epoch 52/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 253.9555 - reconstruction_loss: 249.9707 - kl_loss: 3.9848
# Epoch 53/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.8839 - reconstruction_loss: 249.9015 - kl_loss: 3.9824
# Epoch 54/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 253.8406 - reconstruction_loss: 249.8517 - kl_loss: 3.9889
# Epoch 55/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 253.8213 - reconstruction_loss: 249.8304 - kl_loss: 3.9909
# Epoch 56/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 253.7514 - reconstruction_loss: 249.7711 - kl_loss: 3.9804
# Epoch 57/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 253.6957 - reconstruction_loss: 249.7056 - kl_loss: 3.9902
# Epoch 58/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.6403 - reconstruction_loss: 249.6538 - kl_loss: 3.9864
# Epoch 59/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 253.5994 - reconstruction_loss: 249.6022 - kl_loss: 3.9972
# Epoch 60/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 253.5801 - reconstruction_loss: 249.5892 - kl_loss: 3.9908
# Epoch 61/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.5539 - reconstruction_loss: 249.5569 - kl_loss: 3.9969
# Epoch 62/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 253.4902 - reconstruction_loss: 249.4863 - kl_loss: 4.0040
# Epoch 63/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.4546 - reconstruction_loss: 249.4596 - kl_loss: 3.9950
# Epoch 64/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 253.4204 - reconstruction_loss: 249.4296 - kl_loss: 3.9908
# Epoch 65/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 253.4128 - reconstruction_loss: 249.4127 - kl_loss: 4.0001
# Epoch 66/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.3066 - reconstruction_loss: 249.3063 - kl_loss: 4.0003
# Epoch 67/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 253.3682 - reconstruction_loss: 249.3585 - kl_loss: 4.0097
# Epoch 68/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.2733 - reconstruction_loss: 249.2651 - kl_loss: 4.0082
# Epoch 69/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 253.2382 - reconstruction_loss: 249.2336 - kl_loss: 4.0046
# Epoch 70/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 253.1781 - reconstruction_loss: 249.1799 - kl_loss: 3.9982
# Epoch 71/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.1926 - reconstruction_loss: 249.1987 - kl_loss: 3.9939
# Epoch 72/100
# 1094/1094 [==============================] - 91s 84ms/step - loss: 253.1468 - reconstruction_loss: 249.1428 - kl_loss: 4.0040
# Epoch 73/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 253.1473 - reconstruction_loss: 249.1394 - kl_loss: 4.0079
# Epoch 74/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 253.0495 - reconstruction_loss: 249.0494 - kl_loss: 4.0001
# Epoch 75/100
# 1094/1094 [==============================] - 91s 84ms/step - loss: 253.0788 - reconstruction_loss: 249.0758 - kl_loss: 4.0030
# Epoch 76/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 252.9813 - reconstruction_loss: 248.9856 - kl_loss: 3.9957
# Epoch 77/100
# 1094/1094 [==============================] - 91s 83ms/step - loss: 252.9678 - reconstruction_loss: 248.9625 - kl_loss: 4.0053
# Epoch 78/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 252.9557 - reconstruction_loss: 248.9497 - kl_loss: 4.0060
# Epoch 79/100
# 1094/1094 [==============================] - 93s 85ms/step - loss: 252.9832 - reconstruction_loss: 248.9723 - kl_loss: 4.0109
# Epoch 80/100
# 1094/1094 [==============================] - 91s 84ms/step - loss: 252.9027 - reconstruction_loss: 248.8876 - kl_loss: 4.0151
# Epoch 81/100
# 1094/1094 [==============================] - 92s 84ms/step - loss: 252.9187 - reconstruction_loss: 248.8949 - kl_loss: 4.0239
# Epoch 82/100
# 1094/1094 [==============================] - 98s 89ms/step - loss: 252.8962 - reconstruction_loss: 248.8903 - kl_loss: 4.0059
# Epoch 83/100
# 1094/1094 [==============================] - 95s 87ms/step - loss: 252.7790 - reconstruction_loss: 248.7704 - kl_loss: 4.0086
# Epoch 84/100
# 1094/1094 [==============================] - 95s 87ms/step - loss: 252.8087 - reconstruction_loss: 248.7945 - kl_loss: 4.0142
# Epoch 85/100
# 1094/1094 [==============================] - 95s 87ms/step - loss: 252.7461 - reconstruction_loss: 248.7400 - kl_loss: 4.0061
# Epoch 86/100
# 1094/1094 [==============================] - 91s 84ms/step - loss: 252.7155 - reconstruction_loss: 248.7002 - kl_loss: 4.0153
# Epoch 87/100
# 1094/1094 [==============================] - 89s 82ms/step - loss: 252.7326 - reconstruction_loss: 248.7131 - kl_loss: 4.0195
# Epoch 88/100
# 1094/1094 [==============================] - 90s 82ms/step - loss: 252.6987 - reconstruction_loss: 248.6823 - kl_loss: 4.0164
# Epoch 89/100
# 1094/1094 [==============================] - 89s 81ms/step - loss: 252.7356 - reconstruction_loss: 248.7137 - kl_loss: 4.0219
# Epoch 90/100
# 1094/1094 [==============================] - 90s 82ms/step - loss: 252.6351 - reconstruction_loss: 248.6195 - kl_loss: 4.0157
# Epoch 91/100
# 1094/1094 [==============================] - 89s 82ms/step - loss: 252.6320 - reconstruction_loss: 248.6126 - kl_loss: 4.0194
# Epoch 92/100
# 1094/1094 [==============================] - 89s 81ms/step - loss: 252.5876 - reconstruction_loss: 248.5666 - kl_loss: 4.0210
# Epoch 93/100
# 1094/1094 [==============================] - 90s 82ms/step - loss: 252.5690 - reconstruction_loss: 248.5406 - kl_loss: 4.0284
# Epoch 94/100
# 1094/1094 [==============================] - 90s 82ms/step - loss: 252.5260 - reconstruction_loss: 248.5126 - kl_loss: 4.0134
# Epoch 95/100
# 1094/1094 [==============================] - 90s 82ms/step - loss: 252.5407 - reconstruction_loss: 248.5248 - kl_loss: 4.0159
# Epoch 96/100
# 1094/1094 [==============================] - 89s 82ms/step - loss: 252.5308 - reconstruction_loss: 248.4974 - kl_loss: 4.0334
# Epoch 97/100
# 1094/1094 [==============================] - 89s 82ms/step - loss: 252.4136 - reconstruction_loss: 248.3931 - kl_loss: 4.0205
# Epoch 98/100
# 1094/1094 [==============================] - 89s 82ms/step - loss: 252.4582 - reconstruction_loss: 248.4320 - kl_loss: 4.0262
# Epoch 99/100
# 1094/1094 [==============================] - 89s 82ms/step - loss: 252.3896 - reconstruction_loss: 248.3607 - kl_loss: 4.0290
# Epoch 100/100
# 1094/1094 [==============================] - 90s 82ms/step - loss: 252.3951 - reconstruction_loss: 248.3759 - kl_loss: 4.0192

# %% [markdown]
# Here we are displaying training results according to their latent space vectors.

# %%
def plot_latent(encoder, decoder):
	n = 9
	img_dim = 28
	scale = 2.0
	figsize = 15
	figure = np.zeros((img_dim * n, img_dim * n))

	grid_x = np.linspace(-scale, scale, n)
	grid_y = np.linspace(-scale, scale, n)[::-1]

	for i, yi in enumerate(grid_y):
		for j, xi in enumerate(grid_x):
			z_sample = np.array([[xi, yi]])
			x_decoded = decoder.predict(z_sample)
			images = x_decoded[0].reshape(img_dim, img_dim)
			figure[
				i * img_dim : (i + 1) * img_dim,
				j * img_dim : (j + 1) * img_dim,
			] = images

	plt.figure(figsize =(figsize, figsize))
	start_range = img_dim // 2
	end_range = n * img_dim + start_range + 1
	pixel_range = np.arange(start_range, end_range, img_dim)
	sample_range_x = np.round(grid_x, 1)
	sample_range_y = np.round(grid_y, 1)
	#plt.xticks(pixel_range, sample_range_x)
	#plt.yticks(pixel_range, sample_range_y)
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.imshow(figure, cmap ="Greys_r")
	plt.show()


plot_latent(encoder, decoder)
# Out:
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step

# %% [markdown]
# The scatter plot of the training data generated from the encoder has been generated to get a clear idea of the latent vector values.

# %%
def plot_label_clusters(encoder, decoder, data, test_lab):
	z_mean, _, _ = encoder.predict(data)
	plt.figure(figsize =(12, 10))
	sc = plt.scatter(z_mean[:, 0], z_mean[:, 1], c = test_lab)
	cbar = plt.colorbar(sc, ticks = range(10))
	cbar.ax.set_yticklabels([labels.get(i) for i in range(10)])
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.show()


labels = {0 :"T-shirt / top",
1: "Trouser",
2: "Pullover",
3: "Dress",
4: "Coat",
5: "Sandal",
6: "Shirt",
7: "Sneaker",
8: "Bag",
9: "Ankle boot"}

(x_train, y_train), _ = keras.datasets.fashion_mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255
plot_label_clusters(encoder, decoder, x_train, y_train)
# Out:
# 1875/1875 [==============================] - 7s 4ms/step
